# %%
import os, sys
curr_dir = os.getcwd()
parent_dir = os.path.dirname(curr_dir)
sys.path.insert(0, parent_dir)
curr_dir, parent_dir
# Out:
# ('/home/am/Documents/Software Development/10_Academy Training/week-10/brent-data-analysis/notebooks',
#  '/home/am/Documents/Software Development/10_Academy Training/week-10/brent-data-analysis')

# %%
import pandas as pd
import numpy as np

# %%
raw_data_path = "../data/BrentOilPrices.csv"

# %%
from scripts.data_analysis import BrentDataAnalysis

workflow = BrentDataAnalysis(raw_data_path)
workflow.overview_of_data()
workflow.describe_data()
workflow.identify_missing_values()
workflow.remove_duplicates()
save_path = "../data/BrentOilPrices.csv"
workflows.save_processed_data(save_path)
workflow.plot_time_series()
# Out:
# /home/am/Documents/Software Development/10_Academy Training/week-10/brent-data-analysis/scripts/data_analysis.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   self.data = pd.read_csv(self.file_path, parse_dates=["Date"], index_col="Date")
# **********************************************************************
# ✅ Data loaded successfully!
#
# **********************************************************************
# Overview of the Data:
# Number of Rows: 9011
# Number of Columns: 1
#
# Data Types:
# Price    float64
# dtype: object
#
# First 5 Rows:
#             Price
# Date
# 1987-05-20  18.63
# 1987-05-21  18.45
# 1987-05-22  18.55
# 1987-05-25  18.60
# 1987-05-26  18.63
#
# **********************************************************************
# Basic statistical summary for numerical columns
#               Price
# count  9011.000000
# mean     48.420782
# std      32.860110
# min       9.100000
# 25%      19.050000
# 50%      38.570000
# 75%      70.090000
# max     143.950000
# No categorical or object columns found.
#
# **********************************************************************
# Missing Values:
# Series([], dtype: int64)
#
#
#
# **********************************************************************
# Duplicates removed.
# Number of rows removed for the duplicate rows case: 3996
# Total rows left after duplicate rows removed.
#  5015
#
#
#
# **********************************************************************
