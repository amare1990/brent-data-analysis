# %%
import os, sys
curr_dir = os.getcwd()
parent_dir = os.path.dirname(curr_dir)
sys.path.insert(0, parent_dir)
curr_dir, parent_dir
# Out:
# ('/home/am/Documents/Software Development/10_Academy Training/week-10/brent-data-analysis/notebooks',
#  '/home/am/Documents/Software Development/10_Academy Training/week-10/brent-data-analysis')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
base_dir = "/home/am/Documents/Software Development/10_Academy Training/week-10/brent-data-analysis"

# %%
# Run the pipeline for change point analysis
from scripts.change_point_analysis import ChangePointAnalysis
print(f"\n{'*'*100}\n")
processed_data = f"{base_dir}/data/processed_data.csv"
change_point_analysis = ChangePointAnalysis(processed_data, "1987-05-20", "2022-09-30")
change_point_analysis.download_data()
change_point_analysis.merge_data()
change_point_analysis.scale_data()
change_point_analysis.compare_models()
# Out:
# API key loaded
#
# ****************************************************************************************************
#
# Starting donwloading
# ✅ Data loaded from /home/am/Documents/Software Development/10_Academy Training/week-10/brent-data-analysis/data/processed_data.csv
# Index(['Price'], dtype='object')
# Index: DatetimeIndex(['1987-05-20', '1987-05-21', '1987-05-22', '1987-05-25',
#                '1987-05-29', '1987-06-01', '1987-06-02', '1987-06-03',
#                '1987-06-04', '1987-06-16',
#                ...
#                '2022-10-24', '2022-10-25', '2022-10-26', '2022-10-28',
#                '2022-10-31', '2022-11-01', '2022-11-03', '2022-11-08',
#                '2022-11-09', '2022-11-14'],
#               dtype='datetime64[ns]', name='Date', length=5015, freq=None)
# ----------------------------------------------------------------------------------------------------
# Loading historical data completed!
#
# GDP data downloaded successfully!
#
# Index(['GDP'], dtype='object')
# Index.self.gdp.index
# ----------------------------------------------------------------------------------------------------
#
# Inflation data downloaded successfully!
#
# Index(['CPIAUCSL'], dtype='object')
# Index: DatetimeIndex(['1987-06-01', '1987-07-01', '1987-08-01', '1987-09-01',
#                '1987-10-01', '1987-11-01', '1987-12-01', '1988-01-01',
#                '1988-02-01', '1988-03-01',
#                ...
#                '2021-12-01', '2022-01-01', '2022-02-01', '2022-03-01',
#                '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01',
#                '2022-08-01', '2022-09-01'],
#               dtype='datetime64[ns]', name='DATE', length=424, freq=None)
# ----------------------------------------------------------------------------------------------------
#
# USD Rate data downloaded successfully!
#
# Index(['DEXUSEU'], dtype='object')
# Index: DatetimeIndex(['1999-01-04', '1999-01-05', '1999-01-06', '1999-01-07',
#                '1999-01-08', '1999-01-11', '1999-01-12', '1999-01-13',
#                '1999-01-14', '1999-01-15',
#                ...
#                '2022-09-19', '2022-09-20', '2022-09-21', '2022-09-22',
#                '2022-09-23', '2022-09-26', '2022-09-27', '2022-09-28',
#                '2022-09-29', '2022-09-30'],
#               dtype='datetime64[ns]', name='DATE', length=6195, freq=None)
# ----------------------------------------------------------------------------------------------------
# Merging data...
# Data merged successfully!
#             Price           GDP  CPIAUCSL  DEXUSEU
# Date
# 1987-05-20  18.63  15353.461175       NaN      NaN
# 1987-05-21  18.45  15353.461175       NaN      NaN
# 1987-05-22  18.55  15353.461175       NaN      NaN
# 1987-05-25  18.60  15353.461175       NaN      NaN
# 1987-05-29  18.58  15353.461175       NaN      NaN
# Index(['Price', 'GDP', 'CPIAUCSL', 'DEXUSEU'], dtype='object')
# Index: DatetimeIndex(['1987-05-20', '1987-05-21', '1987-05-22', '1987-05-25',
#                '1987-05-29', '1987-06-01', '1987-06-02', '1987-06-03',
#                '1987-06-04', '1987-06-16',
#                ...
#                '2022-10-24', '2022-10-25', '2022-10-26', '2022-10-28',
#                '2022-10-31', '2022-11-01', '2022-11-03', '2022-11-08',
#                '2022-11-09', '2022-11-14'],
#               dtype='datetime64[ns]', name='Date', length=5015, freq=None)
# Shape: (5015, 4)
# ----------------------------------------------------------------------------------------------------
# Merged data saved as /home/am/Documents/Software Development/10_Academy Training/week-10/brent-data-analysis/merged_data.csv
# Missing values found. Handling missing values...
# Missing values filled with column mean.
# Data scaling complete.
#
# ****************************************************************************************************
#
# Comparing Model Performance
#
#
# ****************************************************************************************************
#
# Fitting VAR model.
#
# 📊 VAR Performance:
# ✅ RMSE: 27.996355665677847
# ✅ MAE: 23.53589130303873
# ✅ R² Score: -0.7135241990649848
# /home/am/Documents/Software Development/10_Academy Training/week-10/brent-data-analysis/v-brent/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 25, Feb, 2025
# Time:                     13:17:35
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                    8.94007
# Nobs:                     4007.00    HQIC:                   8.85487
# Log likelihood:          -40305.8    FPE:                    6688.16
# AIC:                      8.80809    Det(Omega_mle):         6549.77
# --------------------------------------------------------------------
# Results for equation Price
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -1.855218         2.266336           -0.819           0.413
# L1.Price            1.027316         0.015888           64.659           0.000
# L1.CPIAUCSL        -0.002081         0.004017           -0.518           0.605
# L1.DEXUSEU          1.341700         0.918031            1.461           0.144
# L1.GDP              0.000048         0.000068            0.710           0.477
# L2.Price           -0.027090         0.022757           -1.190           0.234
# L2.CPIAUCSL         0.001173         0.004017            0.292           0.770
# L2.DEXUSEU          2.130749         0.955766            2.229           0.026
# L2.GDP             -0.000020         0.000068           -0.293           0.770
# L3.Price           -0.021332         0.022760           -0.937           0.349
# L3.CPIAUCSL        -0.000536         0.004016           -0.133           0.894
# L3.DEXUSEU         -0.817641         0.980174           -0.834           0.404
# L3.GDP              0.000021         0.000068            0.306           0.759
# L4.Price            0.017988         0.022756            0.790           0.429
# L4.CPIAUCSL         0.000294         0.004016            0.073           0.942
# L4.DEXUSEU         -0.571201         0.956209           -0.597           0.550
# L4.GDP              0.000001         0.000068            0.009           0.993
# L5.Price            0.001264         0.015867            0.080           0.937
# L5.CPIAUCSL         0.001985         0.004016            0.494           0.621
# L5.DEXUSEU         -1.810008         0.918816           -1.970           0.049
# L5.GDP              0.000045         0.000068            0.667           0.505
# ==============================================================================
#
# Results for equation CPIAUCSL
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const             233.392849        10.137643           23.022           0.000
# L1.Price           -0.009418         0.071070           -0.133           0.895
# L1.CPIAUCSL        -0.022830         0.017969           -1.271           0.204
# L1.DEXUSEU         -0.349149         4.106482           -0.085           0.932
# L1.GDP              0.000008         0.000303            0.025           0.980
# L2.Price            0.066669         0.101794            0.655           0.513
# L2.CPIAUCSL        -0.023107         0.017967           -1.286           0.198
# L2.DEXUSEU         -0.339956         4.275276           -0.080           0.937
# L2.GDP              0.000003         0.000303            0.011           0.991
# L3.Price           -0.001607         0.101808           -0.016           0.987
# L3.CPIAUCSL        -0.022862         0.017965           -1.273           0.203
# L3.DEXUSEU          2.637894         4.384457            0.602           0.547
# L3.GDP             -0.000002         0.000303           -0.005           0.996
# L4.Price           -0.031968         0.101792           -0.314           0.753
# L4.CPIAUCSL        -0.022707         0.017965           -1.264           0.206
# L4.DEXUSEU         -5.037911         4.277261           -1.178           0.239
# L4.GDP              0.000002         0.000303            0.007           0.994
# L5.Price            0.007329         0.070975            0.103           0.918
# L5.CPIAUCSL        -0.023311         0.017966           -1.297           0.194
# L5.DEXUSEU          0.964942         4.109997            0.235           0.814
# L5.GDP              0.000007         0.000303            0.022           0.982
# ==============================================================================
#
# Results for equation DEXUSEU
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const               0.049519         0.038953            1.271           0.204
# L1.Price            0.000839         0.000273            3.074           0.002
# L1.CPIAUCSL        -0.000081         0.000069           -1.176           0.239
# L1.DEXUSEU          0.314951         0.015779           19.960           0.000
# L1.GDP              0.000001         0.000001            0.488           0.625
# L2.Price           -0.000237         0.000391           -0.607           0.544
# L2.CPIAUCSL         0.000018         0.000069            0.254           0.799
# L2.DEXUSEU          0.282681         0.016427           17.208           0.000
# L2.GDP             -0.000000         0.000001           -0.196           0.845
# L3.Price           -0.000009         0.000391           -0.023           0.982
# L3.CPIAUCSL         0.000020         0.000069            0.288           0.773
# L3.DEXUSEU          0.152732         0.016847            9.066           0.000
# L3.GDP             -0.000000         0.000001           -0.289           0.773
# L4.Price           -0.000445         0.000391           -1.138           0.255
# L4.CPIAUCSL        -0.000057         0.000069           -0.823           0.411
# L4.DEXUSEU          0.122693         0.016435            7.465           0.000
# L4.GDP              0.000000         0.000001            0.173           0.863
# L5.Price           -0.000122         0.000273           -0.447           0.655
# L5.CPIAUCSL         0.000005         0.000069            0.065           0.948
# L5.DEXUSEU          0.117286         0.015792            7.427           0.000
# L5.GDP             -0.000001         0.000001           -1.244           0.213
# ==============================================================================
#
# Results for equation GDP
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const           16049.220144       600.930307           26.707           0.000
# L1.Price           -0.059413         4.212827           -0.014           0.989
# L1.CPIAUCSL        -0.610060         1.065165           -0.573           0.567
# L1.DEXUSEU        -78.520365       243.420464           -0.323           0.747
# L1.GDP             -0.000219         0.017978           -0.012           0.990
# L2.Price           -1.154045         6.034049           -0.191           0.848
# L2.CPIAUCSL        -0.634604         1.065053           -0.596           0.551
# L2.DEXUSEU        -36.184354       253.426069           -0.143           0.886
# L2.GDP              0.000171         0.017975            0.010           0.992
# L3.Price           -1.540024         6.034859           -0.255           0.799
# L3.CPIAUCSL        -0.624985         1.064940           -0.587           0.557
# L3.DEXUSEU        -29.693298       259.898004           -0.114           0.909
# L3.GDP              0.000311         0.017974            0.017           0.986
# L4.Price            4.691749         6.033946            0.778           0.437
# L4.CPIAUCSL        -0.628195         1.064928           -0.590           0.555
# L4.DEXUSEU         12.116297       253.543728            0.048           0.962
# L4.GDP             -0.000116         0.017974           -0.006           0.995
# L5.Price           -1.095966         4.207169           -0.260           0.794
# L5.CPIAUCSL        -0.618405         1.064980           -0.581           0.561
# L5.DEXUSEU         44.976528       243.628789            0.185           0.854
# L5.GDP             -0.000249         0.017969           -0.014           0.989
# ==============================================================================
#
# Correlation matrix of residuals
#                Price  CPIAUCSL   DEXUSEU       GDP
# Price       1.000000  0.015318  0.085348  0.028373
# CPIAUCSL    0.015318  1.000000 -0.001665  0.472635
# DEXUSEU     0.085348 -0.001665  1.000000 -0.001297
# GDP         0.028373  0.472635 -0.001297  1.000000
#
#
#
#
# ****************************************************************************************************
#
# Fitting LSTM model.
#
# Epoch 1/5, Loss: 0.05029647759720683
# Epoch 2/5, Loss: 0.0022618509754538537
# Epoch 3/5, Loss: 0.002028481888119131
# Epoch 4/5, Loss: 0.0017139689126051962
# Epoch 5/5, Loss: 0.001531800965545699
# 📊 LSTM Performance:
# ✅ RMSE: 3.825919106772182
# ✅ MAE: 2.548876818367089
# ✅ R² Score: 0.9680059420072233
# LSTM Performance Metrics:
# RMSE: 3.825919106772182
# MAE: 2.548876818367089
# R² Score: 0.9680059420072233
#   Model       RMSE        MAE  R² Score
# 0   VAR  27.996356  23.535891 -0.713524
# 1  LSTM   3.825919   2.548877  0.968006
#
# ----------------------------------------------------------------------------------------------------
#
# Model with lowest RMSE and MAE is generally the best.
# Higher R² Score (closer to 1) indicates better model fit.
